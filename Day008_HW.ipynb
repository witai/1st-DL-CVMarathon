# %% [markdown]
# # 靜態網頁的資料爬蟲策略
#
#
# * 了解靜態網頁的資料爬蟲策略
# * 認識適用於靜態網頁爬蟲的相關套件工具：Request
# * 認識適用於靜態網頁爬蟲的相關套件工具：BeatifulSoup

# %% [markdown]
# ## 作業目標
#
# 利用 Request + BeatifulSoup 爬取下列兩個網站內容並解析：
#
# 1. Dcared 網址： https://www.dcard.tw/f
# 2. 知乎： https://www.zhihu.com/explore
#
# 並且回答下面問題：
#
# 1. Request 取回之後該怎麼取出資料，資料型態是什麼？
# 2. 為什麼要使用 BeatifulSoup 處理？處理後的型態是什麼？
# 3. 觀察一下知乎回來的資料好像有點怪怪的，該怎麼解決？

# %% [markdown]
# ### 1. Dcard 網址： https://www.dcard.tw/f

# %%
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://www.dcard.tw/f'
r = requests.get(url)
'''
Your Code Here
'''

r.encoding = 'utf-8'
print(r.text[0:3000])
# Out:
# <!DOCTYPE html><html lang="zh-TW"><head prefix="og: http://ogp.me/ns#" itemscope="" itemType="https://schema.org/WebSite"><meta charSet="utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=edge"/><meta name="apple-mobile-web-app-status-bar-style" content="default"/><meta name="application-name" content="Dcard"/><meta name="apple-itunes-app" content="app-id=951353454"/><meta name="theme-color" content="#006aa6"/><meta name="mobile-web-app-capable" content="yes"/><meta name="apple-mobile-web-app-capable" content="yes"/><meta name="supported-color-schemes" content="light"/><meta property="fb:app_id" content="211628828926493"/><meta property="fb:pages" content="178875832200695,577748865730563,1333515469994506,619122564952487,804004803032067,178024805867764"/><meta property="al:ios:app_store_id" content="951353454"/><meta property="al:ios:app_name" content="Dcard"/><meta property="al:android:package" content="com.sparkslab.dcardreader"/><meta property="al:android:app_name" content="Dcard"/><link rel="manifest" href="/_next/static/manifest.json"/><link rel="preconnect" href="https://www.googletagmanager.com" crossorigin="true"/><link rel="preconnect" href="https://fonts.googleapis.com" crossorigin="true"/><link rel="preconnect" href="https://fonts.gstatic.com" crossorigin="true"/><link rel="dns-prefetch" href="https://www.googletagmanager.com"/><link rel="dns-prefetch" href="https://fonts.googleapis.com"/><link rel="dns-prefetch" href="https://fonts.gstatic.com"/><link rel="dns-prefetch" href="https://www.google-analytics.com"/><link rel="dns-prefetch" href="https://sb.scorecardresearch.com"/><link rel="dns-prefetch" href="https://certify.alexametrics.com"/><link rel="dns-prefetch" href="https://cloudfront-labs.amazonaws.com"/><link rel="dns-prefetch" href="https://cdn.amplitude.com"/><link rel="dns-prefetch" href="https://bilanx.dcard.tw"/><link rel="dns-prefetch" href="https://imgur.dcard.tw"/><link rel="dns-prefetch" href="https://megapx-assets.dcard.tw"/><link rel="dns-prefetch" href="https://browser.sentry-cdn.com"/><link rel="dns-prefetch" href="https://gcs.dcard.tw"/><link rel="preload" href="https://fonts.googleapis.com/css2?family=Roboto:wght@400;500;700&amp;display=swap" as="style"/><link rel="stylesheet" href="https://fonts.googleapis.com/css2?family=Roboto:wght@400;500;700&amp;display=swap"/><link rel="icon" type="image/png" sizes="16x16" href="/_next/static/media/icon-16-1daa7474e5fe761a7239d12c56b88680.png"/><link rel="icon" type="image/png" sizes="24x24" href="/_next/static/media/icon-24-7bfd8a52a6756e15edaa617b106a5c55.png"/><link rel="icon" type="image/png" sizes="32x32" href="/_next/static/media/icon-32-54392e6e864b1f822d54a543ee54a0f9.png"/><link rel="icon" type="image/png" sizes="192x192" href="/_next/static/media/icon-192-49149beb434e1f6bccac918f6608564c.png"/><link rel="apple-touch-icon" type="image/png" sizes="57x57" href="/_next/static/media/icon-57-c95fcd930b41dbc6de0495348939582f.png"/><link rel="apple-touch-icon" type="ima

# %%
test = BeautifulSoup(r.text, "html.parser")
print(test.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="zh-TW">
#  <head itemscope="" itemtype="https://schema.org/WebSite" prefix="og: http://ogp.me/ns#">
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="default" name="apple-mobile-web-app-status-bar-style"/>
#   <meta content="Dcard" name="application-name"/>
#   <meta content="app-id=951353454" name="apple-itunes-app"/>
#   <meta content="#006aa6" name="theme-color"/>
#   <meta content="yes" name="mobile-web-app-capable"/>
#   <meta content="yes" name="apple-mobile-web-app-capable"/>
#   <meta content="light" name="supported-color-schemes"/>
#   <meta content="211628828926493" property="fb:app_id"/>
#   <meta content="178875832200695,577748865730563,1333515469994506,619122564952487,804004803032067,178024805867764" property="fb:pages"/>
#   <meta content="951353454" property="al:ios:app_store_id"/>
#   <meta content="Dcard" property="al:ios:app_name"/>
#   <meta content="com.sparkslab.dcardreader" property="al:android:package"/>
#   <meta content="Dcard" property="al:android:app_name"/>
#   <link href="/_next/static/manifest.json" rel="manifest"/>
#   <link crossorigin="true" href="https://www.googletagmanager.com" rel="preconnect"/>
#   <link crossorigin="true" href="https://fonts.googleapis.com" rel="preconnect"/>
#   <link crossorigin="true" href="https://fonts.gstatic.com" rel="preconnect"/>
#   <link href="https://www.googletagmanager.com" rel="dns-prefetch"/>
#   <link href="https://fonts.googleapis.com" rel="dns-prefetch"/>
#   <link href="https://fonts.gstatic.com" rel="dns-prefetch"/>
#   <link href="https://www.google-analytics.com" rel="dns-prefetch"/>
#   <link href="https://sb.scorecardresearch.com" rel="dns-prefetch"/>
#   <link href="https://certify.alexametrics.com" rel="dns-prefetch"/>
#   <link href="https://cloudfront-labs.amazonaws.com" rel="dns-prefetch"/>
#   <link href="https://cdn.amplitude.com" rel="dns-prefetch"/>
#   <link href="https://bilanx.dcard.tw" rel="dns-prefetch"/>
#   <link href="https://imgur.dcard.tw" rel="dns-prefetch"/>
#   <link href="https://megapx-assets.dcard.tw" rel="dns-prefetch"/>
#   <link href="https://browser.sentry-cdn.com" rel="dns-prefetch"/>
#   <link href="https://gcs.dcard.tw" rel="dns-prefetch"/>
#   <link as="style" href="https://fonts.googleapis.com/css2?family=Roboto:wght@400;500;700&amp;display=swap" rel="preload"/>
#   <link href="https://fonts.googleapis.com/css2?family=Roboto:wght@400;500;700&amp;display=swap" rel="stylesheet"/>
#   <link href="/_next/static/media/icon-16-1daa7474e5fe761a7239d12c56b88680.png" rel="icon" sizes="16x16" type="image/png"/>
#   <link href="/_next/static/media/icon-24-7bfd8a52a6756e15edaa617b106a5c55.png" rel="icon" sizes="24x24" type="image/png"/>
#   <link href="/_next/static/media/icon-32-54392e6e864b1f822d54a543ee54a0f9.png" rel="icon" sizes="32x32" type="image/png"/>
#   <link href="/_next/static/media/icon-192-49149beb434e1f6bccac918f6608564c.png" rel="icon" sizes="192x192" type="image/png"/>
#   <link href="/_next/static/media/icon-57-c95fcd930b41dbc6de0495348939582f.png" rel="apple-touch-icon" sizes="57x57" type="image/png"/>
#   <link href="/_next/static/media/icon-72-69b64cb9aadc811dce34ea6ac772cd8f.png" rel="apple-touch-icon" sizes="72x72" type="image/png"/>
#   <link href="/_next/static/media/icon-76-67203a784694f8378d2f51f24970e2f7.png" rel="apple-touch-icon" sizes="76x76" type="image/png"/>
#   <link href="/_next/static/media/icon-114-c58f911deb58868e8cc68ea1e09cc688.png" rel="apple-touch-icon" sizes="114x114" type="image/png"/>
#   <link href="/_next/static/media/icon-120-f3ada61716c0cc460c2cbe72b18fb9b4.png" rel="apple-touch-icon" sizes="120x120" type="image/png"/>
#   <link href="/_next/static/media/icon-144-679d873aa4b58f1117915545d3fdfa1d.png" rel="apple-touch-icon" sizes="144x144" type="image/png"/>
#   <link href="/_next/static/media/icon-152-b7ec982f1f49f590c97611e0e5e9f7f3.png" rel="apple-touch-icon" sizes="152x152" type="image/png"/>
#   <link href="/_next/static/media/icon-180-2665760e1b88b5af7a3cfbdc532bae20.png" rel="apple-touch-icon" sizes="180x180" type="image/png"/>
#   <link href="/_next/static/media/icon-32-54392e6e864b1f822d54a543ee54a0f9.png" rel="shortcut icon" type="image/png"/>
#   <script>
#    (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#       new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#       j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#       'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#       })(window,document,'script','dataLayer','GTM-TWLTW4M');
#   </script>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1, minimum-scale=1" name="viewport"/>
#   <meta content="廣受年輕人喜愛的 Dcard 是台灣最大的匿名交流平台，舉凡時事話題、感情心情、吃喝玩樂、學習工作等，都有卡友陪你聊！" name="description"/>
#   <meta content="廣受年輕人喜愛的 Dcard 是台灣最大的匿名交流平台，舉凡時事話題、感情心情、吃喝玩樂、學習工作等，都有卡友陪你聊！" property="og:description"/>
#   <meta content="website" property="og:type"/>
#   <meta content="廣受年輕人喜愛的 Dcard 是台灣最大的匿名交流平台，舉凡時事話題、感情心情、吃喝玩樂、學習工作等，都有卡友陪你聊！" property="twitter:description"/>
#   <meta content="https://www.dcard.tw/images/landing.png" itemprop="image" name="image"/>
#   <meta content="https://www.dcard.tw/images/landing.png" property="og:image"/>
#   <meta content="https://www.dcard.tw/images/landing.png" property="og:image:secure_url"/>
#   <meta content="https://www.dcard.tw/images/landing.png" property="twitter:image"/>
#   <title>
#    Dcard
#   </title>
#   <link href="https://www.dcard.tw/f" rel="canonical"/>
#   <meta content="https://www.dcard.tw/f" itemprop="url" name="url"/>
#   <meta content="Dcard" property="og:site_name"/>
#   <meta content="Dcard" property="og:title"/>
#   <meta content="https://www.dcard.tw/f" property="og:url"/>
#   <meta content="Dcard" property="twitter:title"/>
#   <meta content="dcard://category/all/%E5%85%A8%E9%83%A8/hot" property="al:android:url"/>
#   <meta content="dcard://category" property="al:ios:url"/>
#   <script type="application/ld+json">
#    {"@type":"CollectionPage","name":"Dcard","url":"https://www.dcard.tw/f","description":"廣受年輕人喜愛的 Dcard 是台灣最大的匿名交流平台，舉凡時事話題、感情心情、吃喝玩樂、學習工作等，都有卡友陪你聊！"}
#   </script>
#   <script type="application/ld+json">
#    {"@type":"BreadcrumbList","itemListElement":[{"@type":"ListItem","position":1,"name":"Dcard","item":"https://www.dcard.tw"},{"@type":"ListItem","position":2,"name":"全部","item":"https://www.dcard.tw/f"}]}
#   </script>
#   <meta content="21" name="next-head-count"/>
#   <link as="style" href="/_next/static/css/c811702b86011dfee7a9.css" rel="preload"/>
#   <link href="/_next/static/css/c811702b86011dfee7a9.css" rel="stylesheet"/>
#   <link as="script" href="/_next/static/chunks/commons.532bf71e6ccb5fc36ebc.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/c165339242bc0b02db108c7bb25f6c2a1f944266.a3349d4b2a8a50614938.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/1a6a343d6d2072c93e5204476ba4a6aed0746115.45df3b44bd2ae2060935.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/bb38ebb74f62df4bbd1dbf7ba1d7c108b187494c.2af708224563f1210256.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/112.c869bd72e5f084b3f4e9.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/4146d37fbdfcf7615748222089b374359ea5cf8e.993c8c2a41e05601178b.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/78d62a35dcc6dedda879910d5b00bd9d449f477e.4e79a3bd75d5bfeb89a7.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/192.0345a3f9d5a0f0eb3627.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/163.927adc2edb2a2a9db4ef.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/fe8bb93dcba62e8ce8a062d724dbc8a69309bd57.171f4bc428160b438c2d.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/138.c434744f85deaddff7b4.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/127.2cd631cb19b2ee6c0069.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/main-61ffc9546dfe1710b1f7.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/webpack-48764ac4c886d9d1a9ef.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/framework.8b0bfc8c33296c8ca2a0.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/commons.532bf71e6ccb5fc36ebc.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/c165339242bc0b02db108c7bb25f6c2a1f944266.a3349d4b2a8a50614938.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/2615915ecadaae8e7ce70c8b9fd4bc6c614e8c38.aded195c1ed26db651fa.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/1a6a343d6d2072c93e5204476ba4a6aed0746115.45df3b44bd2ae2060935.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/0198ba0397f3d2280bf59dfabf54051c64ed74a9.8712e45f26089ee6dd34.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/f1337d3a311b147764a80ab27ada7eddcc6e9eac.3cc0b364f9cb491f4c8d.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/bb38ebb74f62df4bbd1dbf7ba1d7c108b187494c.2af708224563f1210256.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/6c9e99d7c33400159e666f9d7ae595dd8995eb56.f810556c52fc4bb3c03c.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/5d677bd55bade85c998917acf92f30210188694b.632308d1d40902058d84.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/6cd552e4e44b9b6b5f1bb97fbe272e73a3888403.82d106894bd845ebb9fe.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/7cf1033a2b5c2a52e11858d4ddfebc4d4476f8f7.fd3e90524add422fe7d0.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/973751cf784e42c896f01914830f4f7c4d332fbb.6e9df904652768f5110d.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/55b2710b991d307b91ed0706e5d7c372eae2a210.d45a67d46897d2fee023.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/pages/_app-f68e663d0f481c7c2fff.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/77e981c83c500d9bfb35b2a0cf82f7bc1289bcd1.e93d56e118c255d672f0.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/51077693dfb089ddf9a13bc47c2e55b6fda5e277.0df709edce69ee27e1c9.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/581add8810c4100798fbf71839d16e8744b1323f.0cf0cb3c8d756aac75c3.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/6a6b1fac37bb1236994d9ef0b97aa5d25af67a86.aa57f82927f76f4fea2e.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/fb8e81f14044f067d69d30e9e197929f9b701abe.9f96c04835122813f308.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/0b08f87300568bbaea9dde226e5ecc298eb94897.cecf400569fcc2f72468.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/e421b190c155fd7905f6a2b67e900becf64d0c1d.21f3f033ba5062a7b7a3.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/73dea538990fe00a85be111281f4d9d75c4c1777.ab6a402d343749cda345.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/3ef891876f10e6d1dcae18060774305be08e34f1.d0f7020deace869f6a19.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/pages/forum-e8976e7a7fdd171f41dc.js" rel="preload"/>
#   <style data-styled="" data-styled-version="5.1.1">
#    .fwHxVQ{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;vertical-align:top;width:20px;height:20px;fill:#fff;stroke:none;padding:px;-webkit-transition:fill 0.15s cubic-bezier(.4,0,.2,1);transition:fill 0.15s cubic-bezier(.4,0,.2,1);}/*!sc*/
# .fwHxVQ img,.fwHxVQ svg{height:100%;width:100%;}/*!sc*/
# .cRCIzY{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;vertical-align:top;width:24px;height:24px;fill:#fff;stroke:none;padding:px;-webkit-transition:fill 0.15s cubic-bezier(.4,0,.2,1);transition:fill 0.15s cubic-bezier(.4,0,.2,1);}/*!sc*/
# .cRCIzY img,.cRCIzY svg{height:100%;width:100%;}/*!sc*/
# .kWUEba{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;vertical-align:top;width:20px;height:20px;fill:#e1e1e1;stroke:none;padding:px;-webkit-transition:fill 0.15s cubic-bezier(.4,0,.2,1);transition:fill 0.15s cubic-bezier(.4,0,.2,1);}/*!sc*/
# .kWUEba img,.kWUEba svg{height:100%;width:100%;}/*!sc*/
# data-styled.g1[id="sc-1rm1ozc-0"]{content:"fwHxVQ,cRCIzY,kWUEba,"}/*!sc*/
# .jPisqW{display:block;-webkit-flex:1;-ms-flex:1;flex:1;}/*!sc*/
# data-styled.g2[id="ih5c0o-0"]{content:"jPisqW,"}/*!sc*/
# .dBqPat{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;min-width:130px;max-width:640px;height:100%;width:100%;margin-left:px;}/*!sc*/
# data-styled.g4[id="ih5c0o-2"]{content:"dBqPat,"}/*!sc*/
# .hHuYAw{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;box-sizing:border-box;height:40px;padding:10px 13px;outline:none;border:1px solid rgba(0,0,0,0.15);font-size:16px;line-height:normal;cursor:text;-webkit-flex:1;-ms-flex:1;flex:1;border-radius:10px;color:rgba(0,0,0,.85);}/*!sc*/
# .hHuYAw::-webkit-input-placeholder{color:rgba(0,0,0,0.35);}/*!sc*/
# .hHuYAw::-moz-placeholder{color:rgba(0,0,0,0.35);}/*!sc*/
# .hHuYAw:-ms-input-placeholder{color:rgba(0,0,0,0.35);}/*!sc*/
# .hHuYAw::placeholder{color:rgba(0,0,0,0.35);}/*!sc*/
# data-styled.g6[id="ih5c0o-4"]{content:"hHuYAw,"}/*!sc*/
# .krYaWn{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;width:100%;}/*!sc*/
# .krYaWn form{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;background:#00588a;border-radius:4px;overflow:hidden;width:100%;}/*!sc*/
# data-styled.g9[id="sc-1ehu1w3-0"]{content:"krYaWn,"}/*!sc*/
# .evDMiH{-webkit-flex:1;-ms-flex:1;flex:1;border:none;background:none;height:100%;padding:0 10px;font-size:14px;color:#fff;}/*!sc*/
# .evDMiH::-webkit-search-cancel-button{display:none;}/*!sc*/
# .evDMiH::-webkit-input-placeholder{color:rgba(255,255,255,0.75);}/*!sc*/
# .evDMiH::-moz-placeholder{color:rgba(255,255,255,0.75);}/*!sc*/
# .evDMiH:-ms-input-placeholder{color:rgba(255,255,255,0.75);}/*!sc*/
# .evDMiH::placeholder{color:rgba(255,255,255,0.75);}/*!sc*/
# data-styled.g11[id="sc-1ehu1w3-2"]{content:"evDMiH,"}/*!sc*/
# .bGWEMw{background:#006aa6;border:1px solid #00588a;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;border-radius:0 4px 4px 0;padding:0 9px;cursor:pointer;outline:none;}/*!sc*/
# data-styled.g12[id="sc-1ehu1w3-3"]{content:"bGWEMw,"}/*!sc*/
# .lbIsud{width:100%;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;position:relative;-webkit-box-pack:start;-webkit-justify-content:flex-start;-ms-flex-pack:start;justify-content:flex-start;}/*!sc*/
# data-styled.g17[id="ffo8iu-0"]{content:"lbIsud,"}/*!sc*/
# .iFzsWx{position:relative;background-color:#fff;color:rgba(0,0,0,1);cursor:pointer;padding:0 16px;font-weight:500;font-size:16px;line-height:22px;height:60px;line-height:60px;font-size:16px;}/*!sc*/
# .iFzsWx:hover{color:rgba(0,0,0,1);}/*!sc*/
# .iFzsWx::after{content:'';border-bottom:2px solid #3397cf;position:absolute;left:0;bottom:-1px;width:100%;}/*!sc*/
# .gOZCQi{position:relative;background-color:#fff;color:rgba(0,0,0,0.35);cursor:pointer;padding:0 16px;font-weight:500;font-size:16px;line-height:22px;height:60px;line-height:60px;font-size:16px;}/*!sc*/
# .gOZCQi:hover{color:rgba(0,0,0,1);}/*!sc*/
# .gOZCQi::after{content:'';border-bottom:2px solid transparent;position:absolute;left:0;bottom:-1px;width:100%;}/*!sc*/
# data-styled.g18[id="ffo8iu-1"]{content:"iFzsWx,gOZCQi,"}/*!sc*/
# .gPEpjI{background-color:#3397cf !important;}/*!sc*/
# data-styled.g38[id="sc-10brrpi-0"]{content:"gPEpjI,"}/*!sc*/
# .kKaGuz{border-radius:50%;overflow:hidden;}/*!sc*/
# data-styled.g57[id="sc-1heqsqc-0"]{content:"kKaGuz,"}/*!sc*/
# .cobkEp{background:#006ea5;color:#fff;font-size:12.8px;height:20px;width:20px;line-height:20px;text-align:center;border-radius:50%;}/*!sc*/
# data-styled.g58[id="sc-1heqsqc-1"]{content:"cobkEp,"}/*!sc*/
# .qPACF{position:relative;height:120px;padding:16px 0;width:100%;}/*!sc*/
# data-styled.g104[id="sc-8n4pv8-0"]{content:"qPACF,"}/*!sc*/
# .gKDILJ{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;cursor:pointer;}/*!sc*/
# data-styled.g120[id="sc-1kuvyve-0"]{content:"gKDILJ,"}/*!sc*/
# .bpnvkI{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;opacity:0.75;}/*!sc*/
# data-styled.g121[id="sc-1kuvyve-1"]{content:"bpnvkI,"}/*!sc*/
# .gPmczY{display:block;height:20px;width:20px;border-radius:50%;border:2px solid #fff;margin-left:-4px;}/*!sc*/
# .gPmczY:first-child{margin-left:0;}/*!sc*/
# data-styled.g122[id="sc-1kuvyve-2"]{content:"gPmczY,"}/*!sc*/
# .bIYJbX{padding-left:6px;}/*!sc*/
# data-styled.g123[id="sc-1kuvyve-3"]{content:"bIYJbX,"}/*!sc*/
# .dNvklZ{display:grid;max-width:1280px;margin:auto;padding:48px 20px 0 0;grid-template-columns:[start] 208px [mainLeft] auto [mainRight] 300px [end];-webkit-transition:grid-template-columns .5s;transition:grid-template-columns .5s;}/*!sc*/
# data-styled.g156[id="sc-1szhyqg-0"]{content:"dNvklZ,"}/*!sc*/
# .ctfFF{grid-column:start / mainLeft;}/*!sc*/
# data-styled.g157[id="sc-1szhyqg-1"]{content:"ctfFF,"}/*!sc*/
# .kZxHwn{min-width:calc(728px + 24px);grid-column:mainLeft / mainRight;}/*!sc*/
# data-styled.g158[id="sc-1szhyqg-2"]{content:"kZxHwn,"}/*!sc*/
# .GtocX{grid-column:mainRight / end;}/*!sc*/
# data-styled.g159[id="sc-1szhyqg-3"]{content:"GtocX,"}/*!sc*/
# .bImJhr{margin:0 12px;min-height:calc(100vh - 68px);min-width:728px;padding-top:20px;height:100%;}/*!sc*/
# data-styled.g160[id="sc-9fdzn5-0"]{content:"bImJhr,"}/*!sc*/
# .kbYpwI{height:100%;background:#fff;border-radius:4px 4px 0 0;}/*!sc*/
# data-styled.g161[id="sc-9fdzn5-1"]{content:"kbYpwI,"}/*!sc*/
# .hHrnvN{width:60px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;cursor:pointer;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;color:rgba(255,255,255,0.6);height:100%;pointer-events:all;opacity:1;}/*!sc*/
# .hRWyAp{width:px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;padding:0 2px;cursor:pointer;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;color:rgba(255,255,255,0.6);height:100%;pointer-events:all;opacity:1;}/*!sc*/
# data-styled.g163[id="sc-17x0g9b-0"]{content:"hHrnvN,hRWyAp,"}/*!sc*/
# .cugsgk{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;position:relative;line-height:1;color:#fff;}/*!sc*/
# data-styled.g164[id="sc-17x0g9b-1"]{content:"cugsgk,"}/*!sc*/
# .ixTrsr{display:block;height:100%;}/*!sc*/
# data-styled.g167[id="ezgous-0"]{content:"ixTrsr,"}/*!sc*/
# .cOWxiB{height:100%;padding:10px 0;display:block;}/*!sc*/
# data-styled.g168[id="sc-1h3w01r-0"]{content:"cOWxiB,"}/*!sc*/
# .emWQsw{max-width:1280px;height:100%;margin:auto;padding:0 20px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}/*!sc*/
# data-styled.g169[id="sc-1ccznvc-0"]{content:"emWQsw,"}/*!sc*/
# .fXrMZE{height:100%;-webkit-flex:1;-ms-flex:1;flex:1;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;padding:0 16px;}/*!sc*/
# data-styled.g170[id="sc-1ccznvc-1"]{content:"fXrMZE,"}/*!sc*/
# .iDvOMF{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;height:100%;}/*!sc*/
# data-styled.g171[id="sc-1ccznvc-2"]{content:"iDvOMF,"}/*!sc*/
# .kClVql{width:auto;padding:0 16px;}/*!sc*/
# data-styled.g174[id="sc-4hbl5y-0"]{content:"kClVql,"}/*!sc*/
# .cMYlHL{height:100%;width:-webkit-fit-content;width:-moz-fit-content;width:fit-content;}/*!sc*/
# data-styled.g191[id="sc-1tslx79-0"]{content:"cMYlHL,"}/*!sc*/
# .bHsDKc .msew01-0{max-height:calc(100vh - 48px - 5px);overflow:auto;}/*!sc*/
# data-styled.g192[id="n5x8h7-0"]{content:"bHsDKc,"}/*!sc*/
# .kNKMUy{position:fixed;top:0;z-index:11;height:48px;width:100%;background:#006aa6;}/*!sc*/
# data-styled.g193[id="sc-18hjmuk-0"]{content:"kNKMUy,"}/*!sc*/
# .lgXNYK{padding:0 32px;max-width:666px;min-width:200px;height:30px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex:1;-ms-flex:1;flex:1;}/*!sc*/
# data-styled.g194[id="sc-18hjmuk-1"]{content:"lgXNYK,"}/*!sc*/
# .ivXMtf{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;color:rgba(255,255,255,0.6);margin:-3px -5px;}/*!sc*/
# data-styled.g217[id="eygvu1-0"]{content:"ivXMtf,"}/*!sc*/
# .dfooky{color:rgba(255,255,255,0.6);margin:3px 5px;}/*!sc*/
# data-styled.g218[id="eygvu1-1"]{content:"dfooky,"}/*!sc*/
# .kwFGxe{display:block;border:0;width:100%;height:130px;overflow:hidden;}/*!sc*/
# data-styled.g221[id="wk6ojg-0"]{content:"kwFGxe,"}/*!sc*/
# .eLxCoI{position:-webkit-sticky;position:sticky;top:calc( 100vh - 100vh + 58px );margin:20px 0;min-width:300px;min-height:calc(100vh - 88px);width:300px;}/*!sc*/
# .eLxCoI >:not(:last-child){margin-bottom:10px;}/*!sc*/
# data-styled.g229[id="oboeui-0"]{content:"eLxCoI,"}/*!sc*/
# .iEJVZC{font-size:16px;margin:0 10px 0 8px;white-space:nowrap;text-overflow:ellipsis;overflow:hidden;}/*!sc*/
# data-styled.g231[id="sc-1x63gba-1"]{content:"iEJVZC,"}/*!sc*/
# .cFDYxL{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;height:44px;padding:0 10px 0 20px;color:rgba(255,255,255,0.75);cursor:pointer;}/*!sc*/
# .cFDYxL:hover{background-color:rgba(0,0,0,0.2);}/*!sc*/
# data-styled.g232[id="m096xq-0"]{content:"cFDYxL,"}/*!sc*/
# .gIRboB{position:relative;}/*!sc*/
# .gIRboB::after{top:0;right:0;-webkit-transform:translate3d(calc(50% - 1px),calc(-50% + 1px),0);-ms-transform:translate3d(calc(50% - 1px),calc(-50% + 1px),0);transform:translate3d(calc(50% - 1px),calc(-50% + 1px),0);position:absolute;content:'';border-radius:50%;width:10px;height:10px;border:1px solid #fff;background-color:#ea5c5c;display:none;}/*!sc*/
# data-styled.g236[id="gpcsqh-0"]{content:"gIRboB,"}/*!sc*/
# .UapXH{position:relative;width:100%;height:100%;}/*!sc*/
# data-styled.g237[id="sc-4rlot1-0"]{content:"UapXH,"}/*!sc*/
# .dOnrba{position:absolute;top:0;left:0;bottom:0;right:0;}/*!sc*/
# data-styled.g238[id="sc-4rlot1-1"]{content:"dOnrba,"}/*!sc*/
# .fpGTbc{box-sizing:border-box;}/*!sc*/
# data-styled.g240[id="sc-4rlot1-3"]{content:"fpGTbc,"}/*!sc*/
# .cqPjit{--track-radius:3px;--track-size:8px;--transition-duration:200ms;position:absolute;overflow:hidden;border-radius:var(--track-radius);background-color:transparent;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;-webkit-transition:background var(--transition-duration);transition:background var(--transition-duration);left:0;bottom:0;height:var(--track-size);width:100%;}/*!sc*/
# .cqPjit:hover{background-color:rgba(0,0,0,0.3);}/*!sc*/
# data-styled.g243[id="sc-4rlot1-6"]{content:"cqPjit,"}/*!sc*/
# .flcklM{--track-radius:3px;--track-size:8px;--transition-duration:200ms;position:absolute;overflow:hidden;border-radius:var(--track-radius);background-color:transparent;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;-webkit-transition:background var(--transition-duration);transition:background var(--transition-duration);width:var(--track-size);height:100%;top:0;right:0;}/*!sc*/
# .flcklM:hover{background-color:rgba(0,0,0,0.3);}/*!sc*/
# data-styled.g244[id="sc-4rlot1-7"]{content:"flcklM,"}/*!sc*/
# .krgPcu{--thumb-size:6px;--thumb-margin:calc((var(--track-size) - var(--thumb-size)) / 2);cursor:pointer;border-radius:var(--track-radius);background:rgba(0,0,0,0.5);opacity:0;-webkit-transition:opacity var(--transition-duration);transition:opacity var(--transition-duration);height:var(--thumb-size);margin:var(--thumb-margin) 0;}/*!sc*/
# .sc-4rlot1-0:hover .krgPcu{opacity:1;}/*!sc*/
# .sc-4rlot1-5:hover .krgPcu{height:var(--track-size);margin:0;}/*!sc*/
# data-styled.g246[id="sc-4rlot1-9"]{content:"krgPcu,"}/*!sc*/
# .OeTYC{--thumb-size:6px;--thumb-margin:calc((var(--track-size) - var(--thumb-size)) / 2);cursor:pointer;border-radius:var(--track-radius);background:rgba(0,0,0,0.5);opacity:0;-webkit-transition:opacity var(--transition-duration);transition:opacity var(--transition-duration);width:var(--thumb-size);margin:0 var(--thumb-margin);}/*!sc*/
# .sc-4rlot1-0:hover .OeTYC{opacity:1;}/*!sc*/
# .sc-4rlot1-5:hover .OeTYC{width:var(--track-size);margin:0;}/*!sc*/
# data-styled.g247[id="sc-4rlot1-10"]{content:"OeTYC,"}/*!sc*/
# .euHYSq{position:-webkit-sticky;position:sticky;top:68px;height:calc(100vh - 88px);min-width:208px;width:208px;margin:20px 0;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;}/*!sc*/
# data-styled.g248[id="sc-1xg2zzw-0"]{content:"euHYSq,"}/*!sc*/
# .cJhOtt{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;width:30px;height:30px;position:relative;}/*!sc*/
# data-styled.g249[id="sc-1xg2zzw-1"]{content:"cJhOtt,"}/*!sc*/
# .jSnabR{position:relative;}/*!sc*/
# data-styled.g292[id="upagim-0"]{content:"jSnabR,"}/*!sc*/
# body{background-color:#00324e;}/*!sc*/
# data-styled.g312[id="sc-global-MmJWH1"]{content:"sc-global-MmJWH1,"}/*!sc*/
# .jysJzd{border-radius:4px 4px 0 0;}/*!sc*/
# data-styled.g316[id="sc-15kv3jb-0"]{content:"jysJzd,"}/*!sc*/
# .eobiuS{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;font-size:14px;}/*!sc*/
# data-styled.g317[id="sc-6oxm01-0"]{content:"eobiuS,"}/*!sc*/
# .cuMsby{white-space:nowrap;text-overflow:ellipsis;overflow:hidden;}/*!sc*/
# data-styled.g318[id="sc-6oxm01-1"]{content:"cuMsby,"}/*!sc*/
# .hiTIMq{color:rgba(0,0,0,.6);}/*!sc*/
# .hiTIMq:not(:last-child)::after{content:'·';padding:0 0.5em;}/*!sc*/
# data-styled.g319[id="sc-6oxm01-2"]{content:"hiTIMq,"}/*!sc*/
# .hQpPh{-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0;margin-right:8px;}/*!sc*/
# data-styled.g320[id="sc-6oxm01-3"]{content:"hQpPh,"}/*!sc*/
# .klhxjz{grid-area:main;overflow:hidden;}/*!sc*/
# data-styled.g326[id="qtg15c-0"]{content:"klhxjz,"}/*!sc*/
# .dKXZJX{color:rgba(0,0,0,.35);display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;grid-area:footer;overflow:hidden;}/*!sc*/
# data-styled.g327[id="qtg15c-1"]{content:"dKXZJX,"}/*!sc*/
# .idhNkN{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;padding-right:16px;}/*!sc*/
# .idhNkN:last-child{padding-right:0;}/*!sc*/
# data-styled.g328[id="qtg15c-2"]{content:"idhNkN,"}/*!sc*/
# .eVtVFc{padding-right:8px;}/*!sc*/
# data-styled.g329[id="qtg15c-3"]{content:"eVtVFc,"}/*!sc*/
# .gXSRDf{position:relative;z-index:1;}/*!sc*/
# data-styled.g330[id="qtg15c-4"]{content:"gXSRDf,"}/*!sc*/
# .jvIvhj{margin:0 40px;border-bottom:1px solid rgb(233,233,233);position:relative;padding:20px 20px;display:grid;grid-template-areas:'header header' '. .' 'title thumb' '. thumb' 'main thumb' '. thumb' 'footer thumb';grid-template-columns:1fr auto;grid-template-rows:auto 12px auto 4px auto 16px auto;cursor:pointer;-webkit-tap-highlight-color:transparent;}/*!sc*/
# data-styled.g331[id="sc-1v1d5rx-0"]{content:"jvIvhj,"}/*!sc*/
# .jokhD{font-size:14px;grid-area:header;overflow:hidden;}/*!sc*/
# data-styled.g332[id="sc-1v1d5rx-1"]{content:"jokhD,"}/*!sc*/
# .kZjhSU{grid-area:title;white-space:nowrap;text-overflow:ellipsis;overflow:hidden;}/*!sc*/
# data-styled.g333[id="sc-1v1d5rx-2"]{content:"kZjhSU,"}/*!sc*/
# .kPUUNB{font-weight:600;font-size:18px;line-height:25px;color:rgba(0,0,0,1);}/*!sc*/
# .kPUUNB::after{content:'';position:absolute;z-index:0;top:0;left:0;width:100%;height:100%;}/*!sc*/
# data-styled.g334[id="sc-1v1d5rx-3"]{content:"kPUUNB,"}/*!sc*/
# .iSqEKd{font-weight:400;font-size:14px;line-height:20px;white-space:nowrap;text-overflow:ellipsis;overflow:hidden;color:rgba(0,0,0,0.75);}/*!sc*/
# data-styled.g335[id="sc-1v1d5rx-4"]{content:"iSqEKd,"}/*!sc*/
# .gamvcw{margin-right:6px;}/*!sc*/
# data-styled.g337[id="sc-1v1d5rx-6"]{content:"gamvcw,"}/*!sc*/
# .kCzfnz{padding:0 60px;}/*!sc*/
# data-styled.g341[id="sc-1gvwjik-0"]{content:"kCzfnz,"}/*!sc*/
# .hGybZb{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;height:60px;}/*!sc*/
# data-styled.g521[id="sc-1llawk3-0"]{content:"hGybZb,"}/*!sc*/
# .bsQBQI{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;height:100%;-webkit-box-flex:0;-webkit-flex-grow:0;-ms-flex-positive:0;flex-grow:0;}/*!sc*/
# .bsQBQI > *{height:100%;width:100%;}/*!sc*/
# data-styled.g522[id="sc-1llawk3-1"]{content:"bsQBQI,"}/*!sc*/
# .lboGbm{position:relative;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-align-items:flex-start;-webkit-box-align:flex-start;-ms-flex-align:flex-start;align-items:flex-start;background:#fff;border-radius:4px 4px 0 0;border-bottom:1px solid rgba(0,0,0,0.15);position:-webkit-sticky;position:sticky;top:48px;padding:20px 60px 0;z-index:10;}/*!sc*/
# data-styled.g525[id="tylbbx-1"]{content:"lboGbm,"}/*!sc*/
# .lnjwXY{width:100%;z-index:1;}/*!sc*/
# data-styled.g531[id="tylbbx-7"]{content:"lnjwXY,"}/*!sc*/
# .bgurqB{border-radius:4px 4px 0 0;}/*!sc*/
# data-styled.g532[id="sc-19z7wht-0"]{content:"bgurqB,"}/*!sc*/
#   </style>
#  </head>
#  <body>
#   <div id="__next">
#    <div class="sc-18hjmuk-0 kNKMUy">
#     <div class="sc-1ccznvc-0 emWQsw">
#      <div class="sc-1ccznvc-1 fXrMZE">
#       <a class="sc-1h3w01r-0 cOWxiB" href="/f" title="Dcard">
#        <img alt="Dcard" class="ezgous-0 ixTrsr" src="/_next/static/media/logo-2ef7b50901acaa284f36a0484329ec05.svg"/>
#       </a>
#       <div class="sc-18hjmuk-1 lgXNYK">
#        <div class="sc-1ehu1w3-0 krYaWn">
#         <form>
#          <label class="ih5c0o-0 jPisqW">
#           <div class="ih5c0o-2 dBqPat">
#            <input aria-label="搜尋" class="ih5c0o-4 hHuYAw sc-1ehu1w3-2 evDMiH" placeholder="搜尋" type="search" value=""/>
#           </div>
#          </label>
#          <button class="sc-1ehu1w3-3 bGWEMw" disabled="" title="搜尋" type="submit">
#           <span class="sc-1rm1ozc-0 fwHxVQ sc-1ehu1w3-7 bvbdhI" fill="#fff" role="img" size="20">
#            <svg viewbox="0 0 28 28">
#             <path d="M22.9 21.2l-4.5-4.5A7.5 7.5 0 1017 18l4.5 4.5a.5.5 0 00.8 0l.5-.5a.5.5 0 000-.8zm-10.4-3.5a5.6 5.6 0 115.6-5.6 5.6 5.6 0 01-5.6 5.6z">
#             </path>
#            </svg>
#           </span>
#          </button>
#         </form>
#        </div>
#       </div>
#      </div>
#      <div class="sc-1ccznvc-2 iDvOMF" role="navigation">
#       <a class="sc-17x0g9b-0 hHrnvN sc-4hbl5y-0 kClVql" href="/signup" role="button">
#        <span class="sc-17x0g9b-1 cugsgk">
#         註冊 / 登入
#        </span>
#       </a>
#       <div class="sc-1tslx79-0 cMYlHL">
#        <a class="sc-17x0g9b-0 hRWyAp" role="button" title="更多">
#         <span class="sc-17x0g9b-1 cugsgk">
#          <span class="sc-1rm1ozc-0 cRCIzY sc-17x0g9b-2 hVYFOL" fill="#fff" role="img" size="24">
#           <svg viewbox="0 0 24 24">
#            <path d="M11.08 15.62l-4.69-4.69a1.31 1.31 0 01.92-2.24h9.38a1.31 1.31 0 01.92 2.24l-4.69 4.69a1.3 1.3 0 01-1.84 0z">
#            </path>
#            <path d="M0 0h24v24H0z" fill="none">
#            </path>
#           </svg>
#          </span>
#         </span>
#        </a>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="sc-1szhyqg-0 dNvklZ">
#     <div class="sc-1szhyqg-1 ctfFF">
#      <div class="sc-1xg2zzw-0 euHYSq">
#       <a href="/forum/all">
#        <div class="m096xq-0 cFDYxL">
#         <div class="sc-1xg2zzw-1 cJhOtt">
#          <span class="sc-1rm1ozc-0 cRCIzY sc-1xg2zzw-2 pbJgK" fill="#fff" role="img" size="24">
#           <svg viewbox="0 0 24 24">
#            <path d="M18.95 3H5.05A2.04 2.04 0 003 5.04v13.91A2.04 2.04 0 005.05 21h13.9A2.05 2.05 0 0021 18.96V5.03A2.05 2.05 0 0018.95 3zM6.68 17.73a1.64 1.64 0 111.64-1.64 1.64 1.64 0 01-1.64 1.64zm0-4.1A1.64 1.64 0 118.32 12a1.64 1.64 0 01-1.64 1.64zm0-4.08A1.64 1.64 0 118.32 7.9a1.64 1.64 0 01-1.64 1.64zm11.86 6.77a1 1 0 01-1 1h-6.59a1 1 0 01-1-1v-.46a1 1 0 011-1h6.6a1 1 0 011 1zm0-4.1a1 1 0 01-1 1h-6.59a1 1 0 01-1-1v-.45a1 1 0 011-1h6.6a1 1 0 011 1zm0-4.08a1 1 0 01-1 1h-6.59a1 1 0 01-1-1v-.46a1 1 0 011-1h6.6a1 1 0 011 1z" data-name="icon_md_forum">
#            </path>
#           </svg>
#          </span>
#         </div>
#         <div class="sc-1x63gba-1 iEJVZC">
#          所有看板
#         </div>
#        </div>
#       </a>
#       <a href="/forum/popular">
#        <div class="m096xq-0 cFDYxL">
#         <div class="sc-1xg2zzw-1 cJhOtt">
#          <span class="sc-1rm1ozc-0 cRCIzY sc-1xg2zzw-2 pbJgK" fill="#fff" role="img" size="24">
#           <svg viewbox="0 0 24 24">
#            <path d="M19.5 14.5a7.5 7.5 0 01-15 0 12.9 12.9 0 012.21-7.25l.02-.03a.18.18 0 01.04-.05.5.5 0 01.31-.15.51.51 0 01.55.46A3.36 3.36 0 0010.9 10a3.26 3.26 0 003.2-3.5 16.5 16.5 0 00-.32-2.9 1.63 1.63 0 01-.04-.19V3.4a.5.5 0 01.49-.5.51.51 0 01.28.08.45.45 0 01.1.09A15.95 15.95 0 0119.5 14.5zm-3.59-1.55a12.97 12.97 0 00-.22-1.32.5.5 0 00-.83-.27 7.93 7.93 0 01-3.73 1.77 2.94 2.94 0 00-2.63 2.93c0 2.55 3.3 4.32 5.95 1.5a5.75 5.75 0 001.46-4.6z" data-name="ic_hot">
#            </path>
#           </svg>
#          </span>
#         </div>
#         <div class="sc-1x63gba-1 iEJVZC">
#          即時熱門看板
#         </div>
#        </div>
#       </a>
#       <a href="/goods">
#        <div class="m096xq-0 cFDYxL">
#         <div class="sc-1xg2zzw-1 cJhOtt">
#          <span class="sc-1rm1ozc-0 cRCIzY gpcsqh-0 gIRboB" fill="#fff" role="img" size="24">
#           <svg viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg">
#            <path d="M20.962 9l-.994-5a2.156 2.156 0 00-1.987-2H6.019a2.156 2.156 0 00-1.987 2l-.994 5A2.34 2.34 0 004 11.269V20a2 2 0 002 2h12a2 2 0 002-2v-8.731A2.34 2.34 0 0020.962 9zM6.019 10a1 1 0 01-.993-1l.993-5H7v5.042a.993.993 0 01-.981.958zM9 9V4h2v5a1 1 0 01-2 0zm5.5 11h-5v-5.143a.937.937 0 011-.857h3a.937.937 0 011 .857zM15 9a1 1 0 01-2 0V4h2zm2.981 1A.993.993 0 0117 9.042V4h.981l.993 5a1 1 0 01-.993 1z">
#            </path>
#            <path d="M0 0h24v24H0z" fill="none">
#            </path>
#           </svg>
#          </span>
#         </div>
#         <div class="sc-1x63gba-1 iEJVZC">
#          好物研究室
#         </div>
#        </div>
#       </a>
#       <div class="sc-4rlot1-0 UapXH ScrollbarsCustom" style="position:relative">
#        <div class="sc-4rlot1-1 dOnrba ScrollbarsCustom-Wrapper" style="position:absolute;overflow:hidden">
#         <div class="sc-4rlot1-2 cvtRXJ ScrollbarsCustom-Scroller" style="position:absolute;top:0;left:0;bottom:0;right:0;-webkit-overflow-scrolling:touch;overflow-y:hidden;overflow-x:hidden">
#          <div class="sc-4rlot1-3 fpGTbc ScrollbarsCustom-Content" style="padding:0.05px">
#           <span>
#           </span>
#           <span>
#           </span>
#           <span>
#           </span>
#           <span>
#           </span>
#           <span>
#           </span>
#          </div>
#         </div>
#        </div>
#        <div class="sc-4rlot1-5 sc-4rlot1-7 flcklM ScrollbarsCustom-Track ScrollbarsCustom-TrackY" style="display:none">
#         <div class="sc-4rlot1-8 sc-4rlot1-10 OeTYC ScrollbarsCustom-Thumb ScrollbarsCustom-ThumbY" style="touch-action:none">
#         </div>
#        </div>
#        <div class="sc-4rlot1-5 sc-4rlot1-6 cqPjit ScrollbarsCustom-Track ScrollbarsCustom-TrackX" style="display:none">
#         <div class="sc-4rlot1-8 sc-4rlot1-9 krgPcu ScrollbarsCustom-Thumb ScrollbarsCustom-ThumbX" style="touch-action:none">
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="sc-1szhyqg-2 kZxHwn">
#      <div class="sc-9fdzn5-0 bImJhr" role="main">
#       <div class="sc-9fdzn5-1 kbYpwI">
#        <div class="sc-15kv3jb-0 jysJzd">
#         <div class="sc-19z7wht-0 bgurqB">
#          <div class="tylbbx-0 tylbbx-1 lboGbm">
#           <div class="tylbbx-7 lnjwXY">
#            <div class="sc-1llawk3-0 hGybZb">
#             <div class="sc-1llawk3-1 bsQBQI">
#              <div class="ffo8iu-0 lbIsud">
#               <a class="ffo8iu-1 iFzsWx" href="/f?listKey=athena-HK" size="1">
#                本地
#               </a>
#               <a class="ffo8iu-1 gOZCQi" href="/f?pessoal=true" size="1">
#                追蹤
#               </a>
#               <a class="ffo8iu-1 gOZCQi" href="/f?home=true" size="1">
#                全部
#               </a>
#              </div>
#             </div>
#            </div>
#           </div>
#          </div>
#          <div>
#           <div class="sc-1azsmde-0 jxJebT">
#            <div style="padding-top:0;padding-bottom:0">
#             <div data-index="0">
#              <div class="upagim-0 jSnabR">
#               <div style="overflow-x:hidden">
#                <div class="react-swipeable-view-container" style="-webkit-flex-direction:row;flex-direction:row;-webkit-transition:all 0s ease 0s;transition:all 0s ease 0s;direction:ltr;display:flex;will-change:transform">
#                </div>
#               </div>
#              </div>
#             </div>
#             <div data-index="1">
#              <article class="sc-1v1d5rx-0 jvIvhj" data-post-list-viewed-cell-no="2" role="article">
#               <div class="sc-1v1d5rx-1 jokhD">
#                <div class="sc-6oxm01-0 eobiuS">
#                 <div class="sc-6oxm01-3 hQpPh">
#                  <span aria-label="女" class="sc-1rm1ozc-0 kWUEba sc-1heqsqc-0 kKaGuz" role="img" size="20">
#                   <svg viewbox="0 0 40 40">
#                    <path d="M40 20a20 20 0 11-40 0 20 20 0 0140 0" fill="#F48FB1">
#                    </path>
#                    <path d="M28.7 17.5a9.6 9.6 0 00-1.4-4.4l.9-.6S25.5 6 17.9 7.3c-5.5 1-7.7 5.4-7.4 9C10.8 19.8 8.3 31 8.3 31l6.7 1.7a4.6 4.6 0 00-.7 1.1v.1a4.2 4.2 0 00-.4.8l-1.3 3.8a20 20 0 0010.6 1.1L23 37c.4-2-.4-4-2-5 0-1.1 0-3 .5-3.1 3-.6 5.1-2.5 6.2-5.3.3.2.6.2 1 .2a1.5 1.5 0 00-.2-3c.1-1 .2-2.2 0-3.3z" fill="#CB3A6B">
#                    </path>
#                   </svg>
#                  </span>
#                 </div>
#                 <div class="sc-6oxm01-1 cuMsby">
#                  <span class="sc-6oxm01-2 hiTIMq">
#                   匿名
#                  </span>
#                  <span class="sc-6oxm01-2 hiTIMq">
#                   8月5日 10:34
#                  </span>
#                 </div>
#                </div>
#               </div>
#               <h2 class="sc-1v1d5rx-2 kZjhSU">
#                <a class="sc-1v1d5rx-3 kPUUNB" href="/f/hkmacrelationship/p/234171932">
#                 <span>
#                  擺低你既愛情煩惱
#                 </span>
#                </a>
#               </h2>
#               <div class="qtg15c-0 klhxjz">
#                <div class="sc-1v1d5rx-4 iSqEKd">
#                 <span>
#                  想同大家傾訴 大家同另一半既煩惱或者單方面煩惱 講咩都得 18禁都唔介意，p.s 無得wfh好苦悶
#                 </span>
#                </div>
#               </div>
#               <div class="qtg15c-1 dKXZJX">
#                <div class="qtg15c-2 idhNkN">
#                 <div class="sc-1kuvyve-0 gKDILJ">
#                  <div class="sc-1kuvyve-1 bpnvkI" opacity="0.75">
#                   <span class="sc-1rm1ozc-0 kWUEba sc-1kuvyve-2 gPmczY" size="20">
#                    <img alt="愛心" src="/_next/static/media/heartGray-24-1ff8eda3261bd083777921953c7f3037.png" srcset="/_next/static/media/heartGray-24-1ff8eda3261bd083777921953c7f3037.png 24w,/_next/static/media/heartGray-48-657c483b60cd8b88d3b25daf374d1b4a.png 48w"/>
#                   </span>
#                  </div>
#                  <div class="sc-1kuvyve-3 bIYJbX">
#                   346
#                  </div>
#                 </div>
#                </div>
#                <div class="qtg15c-2 idhNkN">
#                 <span class="qtg15c-3 eVtVFc">
#                  回應
#                 </span>
#                 <span>
#                  115
#                 </span>
#                </div>
#                <div class="qtg15c-4 gXSRDf">
#                 <div class="qtg15c-2 idhNkN">
#                  <span class="sc-1rm1ozc-0 kWUEba sc-1v1d5rx-6 gamvcw" role="img" size="20">
#                   <svg viewbox="0 0 24 24">
#                    <path d="M17.65 21.39L12 17.5l-5.65 3.88A1.5 1.5 0 014 20.15V5a2.5 2.5 0 012.5-2.5h11A2.5 2.5 0 0120 5v15.15a1.5 1.5 0 01-2.35 1.24z">
#                    </path>
#                   </svg>
#                  </span>
#                  <span>
#                   收藏
#                  </span>
#                 </div>
#                </div>
#               </div>
#              </article>
#             </div>
#             <div data-index="2">
#              <article class="sc-1v1d5rx-0 jvIvhj" data-post-list-viewed-cell-no="3" role="article">
#               <div class="sc-1v1d5rx-1 jokhD">
#                <div class="sc-6oxm01-0 eobiuS">
#                 <div class="sc-6oxm01-3 hQpPh">
#                  <span aria-label="男" class="sc-1rm1ozc-0 kWUEba sc-1heqsqc-0 kKaGuz" role="img" size="20">
#                   <svg viewbox="0 0 40 40">
#                    <path d="M40 20a20 20 0 11-40 0 20 20 0 0140 0" fill="#81D4FA">
#                    </path>
#                    <path d="M16 7.9C12.4 7.4 9.3 6 9.3 6s5.5 4.3 5 5.3c-.4 1-4.2 0-4.2 0l4 2a9.7 9.7 0 00-1.5 4.6l.1 3.4a1.5 1.5 0 10.8 2.9 8.3 8.3 0 006.2 5.3c.6 0 .6 2 .6 3.2-1.6 1-2.5 3-2 5v2.2a20.2 20.2 0 009.9-1.6l-.7-2.7v-.4l-.2-.4-.2-.4-.2-.3-.2-.3c-.7-1-1.7-1.6-2.9-1.8l.6-2.3s1.4-1 3-2.6l.4 1.3 1.4-2.5.9-1.8s3.8-10.3.8-13.9c-2.6-3-11-1.9-14.7-2.3" fill="#2490BF">
#                    </path>
#                   </svg>
#                  </span>
#                 </div>
#                 <div class="sc-6oxm01-1 cuMsby">
#                  <span class="sc-6oxm01-2 hiTIMq">
#                   香港中文大學
#                  </span>
#                  <span class="sc-6oxm01-2 hiTIMq">
#                   8月5日 12:18
#                  </span>
#                 </div>
#                </div>
#               </div>
#               <h2 class="sc-1v1d5rx-2 kZjhSU">
#                <a class="sc-1v1d5rx-3 kPUUNB" href="/f/hkmacdaily/p/234172335">
#                 <span>
#                  我係好人定蠢人？
#                 </span>
#                </a>
#               </h2>
#               <div class="qtg15c-0 klhxjz">
#                <div class="sc-1v1d5rx-4 iSqEKd">
#                 <span>
#                  背景：1. 呢排疫情嚴重，無聊之下就down咗啲交友Apps識下朋友，睇吓有冇人一齊吹吓水。2. 我住大西北嘅村屋，3. 我好窮，而家做緊part-time，上年11月之後同阿爸阿媽炒咗，跟住我以後都
#                 </span>
#                </div>
#               </div>
#               <div class="qtg15c-1 dKXZJX">
#                <div class="qtg15c-2 idhNkN">
#                 <div class="sc-1kuvyve-0 gKDILJ">
#                  <div class="sc-1kuvyve-1 bpnvkI" opacity="0.75">
#                   <span class="sc-1rm1ozc-0 kWUEba sc-1kuvyve-2 gPmczY" size="20">
#                    <img alt="愛心" src="/_next/static/media/heartGray-24-1ff8eda3261bd083777921953c7f3037.png" srcset="/_next/static/media/heartGray-24-1ff8eda3261bd083777921953c7f3037.png 24w,/_next/static/media/heartGray-48-657c483b60cd8b88d3b25daf374d1b4a.png 48w"/>
#                   </span>
#                  </div>
#                  <div class="sc-1kuvyve-3 bIYJbX">
#                   212
#                  </div>
#                 </div>
#                </div>
#                <div class="qtg15c-2 idhNkN">
#                 <span class="qtg15c-3 eVtVFc">
#                  回應
#                 </span>
#                 <span>
#                  82
#                 </span>
#                </div>
#                <div class="qtg15c-4 gXSRDf">
#                 <div class="qtg15c-2 idhNkN">
#                  <span class="sc-1rm1ozc-0 kWUEba sc-1v1d5rx-6 gamvcw" role="img" size="20">
#                   <svg viewbox="0 0 24 24">
#                    <path d="M17.65 21.39L12 17.5l-5.65 3.88A1.5 1.5 0 014 20.15V5a2.5 2.5 0 012.5-2.5h11A2.5 2.5 0 0120 5v15.15a1.5 1.5 0 01-2.35 1.24z">
#                    </path>
#                   </svg>
#                  </span>
#                  <span>
#                   收藏
#                  </span>
#                 </div>
#                </div>
#               </div>
#              </article>
#             </div>
#             <div data-index="3">
#              <article class="sc-1v1d5rx-0 jvIvhj" data-post-list-viewed-cell-no="4" role="article">
#               <div class="sc-1v1d5rx-1 jokhD">
#                <div class="sc-6oxm01-0 eobiuS">
#                 <div class="sc-6oxm01-3 hQpPh">
#                  <span aria-label="男" class="sc-1rm1ozc-0 kWUEba sc-1heqsqc-0 kKaGuz" role="img" size="20">
#                   <svg viewbox="0 0 40 40">
#                    <path d="M40 20a20 20 0 11-40 0 20 20 0 0140 0" fill="#81D4FA">
#                    </path>
#                    <path d="M16 7.9C12.4 7.4 9.3 6 9.3 6s5.5 4.3 5 5.3c-.4 1-4.2 0-4.2 0l4 2a9.7 9.7 0 00-1.5 4.6l.1 3.4a1.5 1.5 0 10.8 2.9 8.3 8.3 0 006.2 5.3c.6 0 .6 2 .6 3.2-1.6 1-2.5 3-2 5v2.2a20.2 20.2 0 009.9-1.6l-.7-2.7v-.4l-.2-.4-.2-.4-.2-.3-.2-.3c-.7-1-1.7-1.6-2.9-1.8l.6-2.3s1.4-1 3-2.6l.4 1.3 1.4-2.5.9-1.8s3.8-10.3.8-13.9c-2.6-3-11-1.9-14.7-2.3" fill="#2490BF">
#                    </path>
#                   </svg>
#                  </span>
#                 </div>
#                 <div class="sc-6oxm01-1 cuMsby">
#                  <span class="sc-6oxm01-2 hiTIMq">
#                   匿名
#                  </span>
#                  <span class="sc-6oxm01-2 hiTIMq">
#                   8月4日 23:56
#                  </span>
#                 </div>
#                </div>
#               </div>
#               <h2 class="sc-1v1d5rx-2 kZjhSU">
#                <a class="sc-1v1d5rx-3 kPUUNB" href="/f/hkmacrelationship/p/234170486">
#                 <span>
#                  點解交友app一開始就要交換電話？
#                 </span>
#                </a>
#               </h2>
#               <div class="qtg15c-0 klhxjz">
#                <div class="sc-1v1d5rx-4 iSqEKd">
#                 <span>
#                  成日話咩喺交友app到傾唔方便，okay。咁咪用第二個平台，但點解一定要電話？tg可以就咁search名，唔洗交電話出嚟唔係幾好？定係我太保守？傾左10幾個女仔，個個都傾左陣就要電話，咩玩法？
#                 </span>
#                </div>
#               </div>
#               <div class="qtg15c-1 dKXZJX">
#                <div class="qtg15c-2 idhNkN">
#                 <div class="sc-1kuvyve-0 gKDILJ">
#                  <div class="sc-1kuvyve-1 bpnvkI" opacity="0.75">
#                   <span class="sc-1rm1ozc-0 kWUEba sc-1kuvyve-2 gPmczY" size="20">
#                    <img alt="愛心" src="/_next/static/media/heartGray-24-1ff8eda3261bd083777921953c7f3037.png" srcset="/_next/static/media/heartGray-24-1ff8eda3261bd083777921953c7f3037.png 24w,/_next/static/media/heartGray-48-657c483b60cd8b88d3b25daf374d1b4a.png 48w"/>
#                   </span>
#                  </div>
#                  <div class="sc-1kuvyve-3 bIYJbX">
#                   140
#                  </div>
#                 </div>
#                </div>
#                <div class="qtg15c-2 idhNkN">
#                 <span class="qtg15c-3 eVtVFc">
#                  回應
# ...
#                   <svg viewbox="0 0 24 24">
#                    <path d="M17.65 21.39L12 17.5l-5.65 3.88A1.5 1.5 0 014 20.15V5a2.5 2.5 0 012.5-2.5h11A2.5 2.5 0 0120 5v15.15a1.5 1.5 0 01-2.35 1.24z">
#                    </path>
#                   </svg>
#                  </span>
#                  <span>
#                   收藏
#                  </span>
#                 </div>
#                </div>
#               </div>
#              </article>
#             </div>
#             <div data-index="31">
#              <article class="sc-1v1d5rx-0 jvIvhj" data-post-list-viewed-cell-no="32" role="article">
#               <div class="sc-1v1d5rx-1 jokhD">
#                <div class="sc-6oxm01-0 eobiuS">
#                 <div class="sc-6oxm01-3 hQpPh">
#                  <span aria-label="男" class="sc-1rm1ozc-0 kWUEba sc-1heqsqc-0 kKaGuz" role="img" size="20">
#                   <svg viewbox="0 0 40 40">
#                    <path d="M40 20a20 20 0 11-40 0 20 20 0 0140 0" fill="#81D4FA">
#                    </path>
#                    <path d="M16 7.9C12.4 7.4 9.3 6 9.3 6s5.5 4.3 5 5.3c-.4 1-4.2 0-4.2 0l4 2a9.7 9.7 0 00-1.5 4.6l.1 3.4a1.5 1.5 0 10.8 2.9 8.3 8.3 0 006.2 5.3c.6 0 .6 2 .6 3.2-1.6 1-2.5 3-2 5v2.2a20.2 20.2 0 009.9-1.6l-.7-2.7v-.4l-.2-.4-.2-.4-.2-.3-.2-.3c-.7-1-1.7-1.6-2.9-1.8l.6-2.3s1.4-1 3-2.6l.4 1.3 1.4-2.5.9-1.8s3.8-10.3.8-13.9c-2.6-3-11-1.9-14.7-2.3" fill="#2490BF">
#                    </path>
#                   </svg>
#                  </span>
#                 </div>
#                 <div class="sc-6oxm01-1 cuMsby">
#                  <span class="sc-6oxm01-2 hiTIMq">
#                   香港中文大學
#                  </span>
#                  <span class="sc-6oxm01-2 hiTIMq">
#                   8月5日 14:21
#                  </span>
#                 </div>
#                </div>
#               </div>
#               <h2 class="sc-1v1d5rx-2 kZjhSU">
#                <a class="sc-1v1d5rx-3 kPUUNB" href="/f/hkmacdaily/p/234172893">
#                 <span>
#                  飲茶定飲水?
#                 </span>
#                </a>
#               </h2>
#               <div class="qtg15c-0 klhxjz">
#                <div class="sc-1v1d5rx-4 iSqEKd">
#                 <span>
#                  平時出街一定會買茶飲，依家屋企都係得茶 都唔會煲水，係咪得我屋企係咁，我媽成日話飲茶降血脂 但當水咁飲認真呢⋯⋯
#                 </span>
#                </div>
#               </div>
#               <div class="qtg15c-1 dKXZJX">
#                <div class="qtg15c-2 idhNkN">
#                 <div class="sc-1kuvyve-0 gKDILJ">
#                  <div class="sc-1kuvyve-1 bpnvkI" opacity="0.75">
#                   <span class="sc-1rm1ozc-0 kWUEba sc-1kuvyve-2 gPmczY" size="20">
#                    <img alt="愛心" src="/_next/static/media/heartGray-24-1ff8eda3261bd083777921953c7f3037.png" srcset="/_next/static/media/heartGray-24-1ff8eda3261bd083777921953c7f3037.png 24w,/_next/static/media/heartGray-48-657c483b60cd8b88d3b25daf374d1b4a.png 48w"/>
#                   </span>
#                  </div>
#                  <div class="sc-1kuvyve-3 bIYJbX">
#                   10
#                  </div>
#                 </div>
#                </div>
#                <div class="qtg15c-2 idhNkN">
#                 <span class="qtg15c-3 eVtVFc">
#                  回應
#                 </span>
#                 <span>
#                  4
#                 </span>
#                </div>
#                <div class="qtg15c-4 gXSRDf">
#                 <div class="qtg15c-2 idhNkN">
#                  <span class="sc-1rm1ozc-0 kWUEba sc-1v1d5rx-6 gamvcw" role="img" size="20">
#                   <svg viewbox="0 0 24 24">
#                    <path d="M17.65 21.39L12 17.5l-5.65 3.88A1.5 1.5 0 014 20.15V5a2.5 2.5 0 012.5-2.5h11A2.5 2.5 0 0120 5v15.15a1.5 1.5 0 01-2.35 1.24z">
#                    </path>
#                   </svg>
#                  </span>
#                  <span>
#                   收藏
#                  </span>
#                 </div>
#                </div>
#               </div>
#              </article>
#             </div>
#            </div>
#            <div style="display:block">
#             <div class="sc-1gvwjik-0 kCzfnz">
#              <div class="sc-8n4pv8-0 qPACF">
#               <svg height="100%" preserveaspectratio="none" viewbox="0 0 100 100" width="100%">
#                <defs>
#                 <lineargradient gradientunits="userSpaceOnUse" id="lg" x1="-100%" x2="200%" y1="0" y2="0">
#                  <stop class="sc-14tf9lo-0 bkgtNS" stop-color="#f2f3f4">
#                   <animate attributename="offset" dur="1s" repeatcount="indefinite" values="0;0.8">
#                   </animate>
#                  </stop>
#                  <stop class="sc-14tf9lo-1 LZHwH" stop-color="#efefef">
#                   <animate attributename="offset" dur="1s" repeatcount="indefinite" values="0.1;0.9">
#                   </animate>
#                  </stop>
#                  <stop class="sc-14tf9lo-0 bkgtNS" stop-color="#f2f3f4">
#                   <animate attributename="offset" dur="1s" repeatcount="indefinite" values="0.2;1">
#                   </animate>
#                  </stop>
#                 </lineargradient>
#                </defs>
#                <g fill="url(#lg)">
#                 <rect height="16" width="30" x="0" y="0">
#                 </rect>
#                 <rect height="16" width="95" x="0" y="28">
#                 </rect>
#                 <rect height="16" width="50" x="0" y="56">
#                 </rect>
#                 <rect height="16" width="35" x="0" y="84">
#                 </rect>
#                </g>
#               </svg>
#              </div>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="sc-1szhyqg-3 GtocX">
#      <aside class="oboeui-0 eLxCoI">
#       <div style="height:250px;width:300px">
#        <div id="div-gpt-ad-1458631742813-0" style="height:250px;width:300px">
#        </div>
#       </div>
#       <div style="height:250px;width:300px">
#        <div id="div-gpt-ad-1466065536619-0" style="height:250px;width:300px">
#        </div>
#       </div>
#       <iframe allow="encrypted-media" class="wk6ojg-0 kwFGxe" loading="lazy" src="about:blank">
#       </iframe>
#       <div style="height:600px;width:300px">
#        <div id="div-gpt-ad-1582095045953-0" style="height:600px;width:300px">
#        </div>
#       </div>
#       <div style="height:250px;width:300px">
#        <div id="div-gpt-ad-1582095257338-0" style="height:250px;width:300px">
#        </div>
#       </div>
#       <div style="height:600px;width:300px">
#        <div id="div-gpt-ad-1458631598292-0" style="height:600px;width:300px">
#        </div>
#       </div>
#       <div class="eygvu1-0 ivXMtf">
#        <a class="eygvu1-1 dfooky" href="/terms" target="_blank">
#         服務條款
#        </a>
#        <a class="eygvu1-1 dfooky" href="https://faq.dcard.tw/" target="_blank">
#         常見問題
#        </a>
#        <a class="eygvu1-1 dfooky" href="/brand/dcard_brand_guidelines.pdf" target="_blank">
#         品牌識別
#        </a>
#        <a class="eygvu1-1 dfooky" href="https://join.dcard.today/" target="_blank">
#         徵才
#        </a>
#        <a class="eygvu1-1 dfooky" href="/cdn-cgi/l/email-protection#bfddcaccd6d1daccccffdbdcdecddb91dcdc">
#         商業合作
#        </a>
#       </div>
#      </aside>
#     </div>
#    </div>
#   </div>
#   <noscript>
#    <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-TWLTW4M" style="display:none;visibility:hidden" width="0">
#    </iframe>
#   </noscript>
#   <noscript>
#    <img src="https://sb.scorecardresearch.com/p?c1=2&amp;c2=33827916&amp;cv=2.0&amp;cj=1"/>
#   </noscript>
#   <script data-cfasync="false" src="/cdn-cgi/scripts/5c5dd728/cloudflare-static/email-decode.min.js">
#   </script>
#   <script id="__NEXT_DATA__" type="application/json">
#    {"props":{"pageProps":{"layoutInitialProps":{"layoutInitialProps":{"layoutInitialProps":{},"componentInitialProps":{}},"componentInitialProps":{}},"componentInitialProps":{"query":{"listKey":"athena-HK"},"paginationOptions":{"listKey":"athena-HK"},"country":"HK","tabs":[{"uiType":"button","alias":"athena-HK","name":"本地","listType":"paging","payload":{"listKey":"athena-HK"},"isHome":false},{"uiType":"button","alias":"subscribe","name":"追蹤","listType":"legacy","isHome":false},{"uiType":"dropdown","alias":"all","name":"全部","listType":"legacy","uiPayload":{"dropdownItems":[{"uiType":"button","alias":"hot","name":"熱門文章","listType":"legacy","isHome":true},{"uiType":"button","alias":"latest","name":"最新文章","listType":"legacy","isHome":false}]},"isHome":true}],"isForumRulePage":false}},"isLogin":false,"isMobile":false,"initialState":{"adItem":{"data":{"558bae61-cb3c-4604-b281-473b6bf1047d":[],"f0fc1371-7da6-472b-be89-6392f8869ea4":[],"2ff05f32-46b1-480c-9a6d-6ccbe55b7699":[],"a0d23a73-66bb-4704-af18-286c6b0292f9":[],"63463c6f-e951-4d18-b559-6e6c5e629ec3":[],"e7b65598-5ac3-4c4e-83e5-255e6f68ad2a":[],"d1555d99-c344-499a-b0ee-fadfa2f2b216":[],"adUnitId=558bae61-cb3c-4604-b281-473b6bf1047d":[{"provider":"google","id":"/146730420/Desktop-Right-Top"}],"adUnitId=f0fc1371-7da6-472b-be89-6392f8869ea4":[{"provider":"google","id":"/146730420/Desktop-Beyond-FB"}],"adUnitId=2ff05f32-46b1-480c-9a6d-6ccbe55b7699":[{"provider":"google","id":"/146730420/Desktop-Right3"}],"adUnitId=a0d23a73-66bb-4704-af18-286c6b0292f9":[{"provider":"google","id":"/146730420/Desktop-Right4"}],"adUnitId=63463c6f-e951-4d18-b559-6e6c5e629ec3":[{"provider":"google","id":"/146730420/Desktop-RightBottom-Bottom"}],"adUnitId=e7b65598-5ac3-4c4e-83e5-255e6f68ad2a":[{"provider":"google","id":"/146730420/Desktop-Article-Bottom"}],"adUnitId=d1555d99-c344-499a-b0ee-fadfa2f2b216":[{"provider":"google","id":"/146730420/Desktop-Comments"}],"adUnitId=e4d31040-b6b8-4479-9585-a28bd1c16832":[{"provider":"google","id":"/146730420/Mobile-Web-Screen-Top"}],"adUnitId=0c24cee5-97e0-486b-9dc1-b7d36bea93cb":[{"provider":"google","id":"/146730420/Mobile-Web-Article-End"}],"adUnitId=49317a19-f96f-42df-9dee-76bf1d62b6f9":[{"provider":"google","id":"/146730420/Mweb-Popular-Comments"}],"adUnitId=b29a047c-6238-449a-8355-2b5651ebe5b1":[{"provider":"google","id":"/146730420/Mweb-Comments"}],"adUnitId=88647537-2142-4839-88d4-780a6b7bf0e4":[{"provider":"google","id":"/146730420/Mobile-Web-Screen-Bottom"}]},"error":null,"loading":false,"fetched":true},"adUnit":{"data":{},"error":null,"paginations":{},"paging":{"head":{},"pageKey":{},"nextKey":{}},"listKeyOfPages":{},"idOfPrimaryKeys":{}},"app":{"loading":false,"fetched":false,"data":{"isLogin":false,"isMobile":false,"ipCountry":"HK"}},"auth":{"socialLogin":{},"appleLogin":{}},"banner":{"loading":false,"fetched":false,"data":{},"paginations":{},"paging":{"head":{},"pageKey":{},"nextKey":{}}},"channel":{"loading":false,"fetched":false,"data":{},"paginations":{},"paging":{"head":{},"pageKey":{},"nextKey":{}},"unread":0},"collection":{"loading":false,"fetched":false,"data":{},"paginations":{},"paging":{"head":{},"pageKey":{},"nextKey":{}}},"comment":{"data":{},"error":null,"paginations":{},"paging":{"head":{},"pageKey":{},"nextKey":{}},"listKeyOfPages":{},"idOfPrimaryKeys":{}},"commentDraft":{"data":{},"error":null,"paginations":{},"paging":{"head":{},"pageKey":{},"nextKey":{}},"listKeyOfPages":{},"idOfPrimaryKeys":{}},"configs":{"loading":false,"fetched":false,"data":{}},"country":{"data":{},"loading":false,"fetched":false},"dadasCampaign":{"data":{},"error":null,"paginations":{},"paging":{"head":{},"pageKey":{},"nextKey":{}},"listKeyOfPages":{},"idOfPrimaryKeys":{}},"dadasCampaignStatus":{"data":{},"error":null,"loading":false,"fetched":false},"dadasSurveyTeam":{"data":{},"error":null,"loading":false,"fetched":false},"dcard":{"data":{},"error":null,"loading":false,"fetched":false},"delayModal":{"stack":[]},"department":{"loading":false,"fetched":false,"data" ...
#   </script>
#   <script nomodule="" src="/_next/static/chunks/polyfills-6b140d9f9709371c4a25.js">
#   </script>
#   <script async="" src="/_next/static/chunks/112.c869bd72e5f084b3f4e9.js">
#   </script>
#   <script async="" src="/_next/static/chunks/4146d37fbdfcf7615748222089b374359ea5cf8e.993c8c2a41e05601178b.js">
#   </script>
#   <script async="" src="/_next/static/chunks/78d62a35dcc6dedda879910d5b00bd9d449f477e.4e79a3bd75d5bfeb89a7.js">
#   </script>
#   <script async="" src="/_next/static/chunks/192.0345a3f9d5a0f0eb3627.js">
#   </script>
#   <script async="" src="/_next/static/chunks/163.927adc2edb2a2a9db4ef.js">
#   </script>
#   <script async="" src="/_next/static/chunks/fe8bb93dcba62e8ce8a062d724dbc8a69309bd57.171f4bc428160b438c2d.js">
#   </script>
#   <script async="" src="/_next/static/chunks/138.c434744f85deaddff7b4.js">
#   </script>
#   <script async="" src="/_next/static/chunks/127.2cd631cb19b2ee6c0069.js">
#   </script>
#   <script async="" src="/_next/static/chunks/main-61ffc9546dfe1710b1f7.js">
#   </script>
#   <script async="" src="/_next/static/chunks/webpack-48764ac4c886d9d1a9ef.js">
#   </script>
#   <script async="" src="/_next/static/chunks/framework.8b0bfc8c33296c8ca2a0.js">
#   </script>
#   <script async="" src="/_next/static/chunks/commons.532bf71e6ccb5fc36ebc.js">
#   </script>
#   <script async="" src="/_next/static/chunks/c165339242bc0b02db108c7bb25f6c2a1f944266.a3349d4b2a8a50614938.js">
#   </script>
#   <script async="" src="/_next/static/chunks/2615915ecadaae8e7ce70c8b9fd4bc6c614e8c38.aded195c1ed26db651fa.js">
#   </script>
#   <script async="" src="/_next/static/chunks/1a6a343d6d2072c93e5204476ba4a6aed0746115.45df3b44bd2ae2060935.js">
#   </script>
#   <script async="" src="/_next/static/chunks/0198ba0397f3d2280bf59dfabf54051c64ed74a9.8712e45f26089ee6dd34.js">
#   </script>
#   <script async="" src="/_next/static/chunks/f1337d3a311b147764a80ab27ada7eddcc6e9eac.3cc0b364f9cb491f4c8d.js">
#   </script>
#   <script async="" src="/_next/static/chunks/bb38ebb74f62df4bbd1dbf7ba1d7c108b187494c.2af708224563f1210256.js">
#   </script>
#   <script async="" src="/_next/static/chunks/6c9e99d7c33400159e666f9d7ae595dd8995eb56.f810556c52fc4bb3c03c.js">
#   </script>
#   <script async="" src="/_next/static/chunks/5d677bd55bade85c998917acf92f30210188694b.632308d1d40902058d84.js">
#   </script>
#   <script async="" src="/_next/static/chunks/6cd552e4e44b9b6b5f1bb97fbe272e73a3888403.82d106894bd845ebb9fe.js">
#   </script>
#   <script async="" src="/_next/static/chunks/7cf1033a2b5c2a52e11858d4ddfebc4d4476f8f7.fd3e90524add422fe7d0.js">
#   </script>
#   <script async="" src="/_next/static/chunks/973751cf784e42c896f01914830f4f7c4d332fbb.6e9df904652768f5110d.js">
#   </script>
#   <script async="" src="/_next/static/chunks/55b2710b991d307b91ed0706e5d7c372eae2a210.d45a67d46897d2fee023.js">
#   </script>
#   <script async="" src="/_next/static/chunks/pages/_app-f68e663d0f481c7c2fff.js">
#   </script>
#   <script async="" src="/_next/static/chunks/77e981c83c500d9bfb35b2a0cf82f7bc1289bcd1.e93d56e118c255d672f0.js">
#   </script>
#   <script async="" src="/_next/static/chunks/51077693dfb089ddf9a13bc47c2e55b6fda5e277.0df709edce69ee27e1c9.js">
#   </script>
#   <script async="" src="/_next/static/chunks/581add8810c4100798fbf71839d16e8744b1323f.0cf0cb3c8d756aac75c3.js">
#   </script>
#   <script async="" src="/_next/static/chunks/6a6b1fac37bb1236994d9ef0b97aa5d25af67a86.aa57f82927f76f4fea2e.js">
#   </script>
#   <script async="" src="/_next/static/chunks/fb8e81f14044f067d69d30e9e197929f9b701abe.9f96c04835122813f308.js">
#   </script>
#   <script async="" src="/_next/static/chunks/0b08f87300568bbaea9dde226e5ecc298eb94897.cecf400569fcc2f72468.js">
#   </script>
#   <script async="" src="/_next/static/chunks/e421b190c155fd7905f6a2b67e900becf64d0c1d.21f3f033ba5062a7b7a3.js">
#   </script>
#   <script async="" src="/_next/static/chunks/73dea538990fe00a85be111281f4d9d75c4c1777.ab6a402d343749cda345.js">
#   </script>
#   <script async="" src="/_next/static/chunks/3ef891876f10e6d1dcae18060774305be08e34f1.d0f7020deace869f6a19.js">
#   </script>
#   <script async="" src="/_next/static/chunks/pages/forum-e8976e7a7fdd171f41dc.js">
#   </script>
#   <script async="" src="/_next/static/966560dffaf9a47180f48b8936456e8fdc8cd040/_buildManifest.js">
#   </script>
#   <script async="" src="/_next/static/966560dffaf9a47180f48b8936456e8fdc8cd040/_ssgManifest.js">
#   </script>
#  </body>
# </html>
# <class 'bs4.BeautifulSoup'>

# %%
print(type(test))
# Out:
# <class 'bs4.BeautifulSoup'>

# %%
title = test.find_all('a')

for tag in title:
    print(tag.string)
# Out:
# None
# 註冊 / 登入
# None
# None
# None
# None
# 本地
# 追蹤
# 全部
# 擺低你既愛情煩惱
# 我係好人定蠢人？
# 點解交友app一開始就要交換電話？
# 嗰一年，新嚟嘅佢教f1 我讀中四下學期
# 點解咁多人死 唔見我死？
# 幼教Hd想升上degree
# 屋企本身有部電競notebook仲買唔買macbook好😭
# 如果你可以許三個願望喺另一半到令大家拍拖更開心
# 請問dcard信件室係咪壞咗？
# 唔係想問嘢 單純想呻
# 睇完支那pua個po，有感而發
# 抽卡潛水
# 有冇人讀樹仁社工？
# 幾時先可以返學校開枱
# 同大學同學frd?
# 學生記者唔通就唔係記者?
# Macbook駛唔駛買Office🤔
# 一場交就可以令友誼疏遠
# Back to school優惠抵啲定大專ownership抵啲？🧐
# 遇到心動嘅人就會逃避
# hd申請政府資助一問
# 配藥高級文憑
# HKU BA
# 拜完月老之後
# 買咗個銀包比bf但佢唔捨得用
# 男仔想揾洗面奶/護膚品，求推薦😷
# dse英文1想考IELTS
# 有冇人都有靜脈曲張
# 同女朋友一齊咗三年分手💔
# 飲茶定飲水?
# 服務條款
# 常見問題
# 品牌識別
# 徵才
# 商業合作

# %%
print('Request 取回之後該怎麼取出資料，資料型態是什麼？ =>')

'''
Your Code Here
'''
# Out:
# Request 取回之後該怎麼取出資料，資料型態是什麼？ =>
# '\nYour Code Here\n'

# %%
print('為什麼要使用 BeatifulSoup 處理？處理後的型態是什麼？ => ')

'''
Your Code Here
'''
# Out:
# 為什麼要使用 BeatifulSoup 處理？處理後的型態是什麼？ =>
# '\nYour Code Here\n'

# %% [markdown]
# ### 2. 知乎： https://www.zhihu.com/explore

# %%
url = 'https://www.zhihu.com/explore'
r = requests.get(url)
r.encoding = 'utf-8'

print(r.text[0:600])
# Out:
# <html>
# <head><title>400 Bad Request</title></head>
# <body bgcolor="white">
# <center><h1>400 Bad Request</h1></center>
# <hr><center>openresty</center>
# </body>
# </html>

# %% [markdown]
# ### 3. 觀察一下知乎回來的資料好像有點怪怪的，該怎麼解決？

# %%
import requests
url = 'https://www.zhihu.com/explore'

'''
Your Code Here
'''
r = requests.get(url)

r.encoding = 'utf-8'
print(r.text[0:600])
# Out:
# <html>
# <head><title>400 Bad Request</title></head>
# <body bgcolor="white">
# <center><h1>400 Bad Request</h1></center>
# <hr><center>openresty</center>
# </body>
# </html>
